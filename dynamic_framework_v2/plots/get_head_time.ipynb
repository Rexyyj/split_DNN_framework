# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
path = "../measurements/direct_split_1/time.csv"

# %%
df = pd.read_csv(path)

# %%
df.mean()
# Out:
# frame_id          226.000000
# head_time           4.734569
# serialize_time      0.000000
# tail_time           0.000000
# dtype: float64
