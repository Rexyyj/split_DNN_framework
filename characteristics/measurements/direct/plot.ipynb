# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch

# %%
l2_df = pd.read_csv("./layer2.csv")
l4_df = pd.read_csv("./layer4.csv")
l6_df = pd.read_csv("./layer6.csv")
l8_df = pd.read_csv("./layer8.csv")

# %%
l2_df.head()
# Out:
#    split_layer      rank  sparsity  regularity  pictoriality  decomposability  \
# 0            2  193.8125       0.0    0.849338      0.880836        -0.863582
# 1            2  197.8125       0.0    0.839837      0.873553        -0.902043
# 2            2  194.0625       0.0    0.859712      0.892781        -0.865986
# 3            2  195.8750       0.0    0.853590      0.892187        -0.883413
# 4            2  197.6875       0.0    0.828454      0.867051        -0.900841
#
#    jpeg_ratio   jpeg_snr  jpeg_mse  decomposition_ratio  decomposition_snr  \
# 0    7.768938  28.483405  0.002284             0.536601          86.943026
# 1    6.457268  28.416262  0.002769             0.525750          89.273586
# 2    7.511926  27.761316  0.002796             0.535910          86.342659
# 3    7.026924  28.015864  0.002787             0.530951          88.059616
# 4    5.946443  27.901051  0.003768             0.526083          90.888462
#
# ...

# %%
plt.figure(figsize=(6,4))
plt.plot(l2_df["pictoriality"],label="layer2")
plt.plot(l4_df["pictoriality"],label="layer4")
plt.plot(l6_df["pictoriality"],label="layer6")
plt.plot(l8_df["pictoriality"],label="layer8")
plt.legend()
plt.grid()
plt.xlabel("Tensor sequency")
plt.ylabel("Pictoriality")
# Out:
# Text(0, 0.5, 'Pictoriality')
