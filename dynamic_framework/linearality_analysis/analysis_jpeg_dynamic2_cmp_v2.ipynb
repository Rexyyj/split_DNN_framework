# %%
from scipy.interpolate import griddata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../measurements/JPEG_manager_dyanmic2/characteristic.csv")
# df = pd.read_csv("../measurements/JPEG_manager_sparsity/characteristic.csv")

# %%
df.head()
# Out:
#    pruning_thresh  quality  technique     bandwidth  mAP_drop  frame_id  \
# 0            0.05       92          1  2.498029e+07        40         1
# 1            0.05       92          1  2.492123e+07        40         2
# 2            0.05       92          1  2.482305e+07        40         3
# 3            0.05       92          1  2.468615e+07        40         4
# 4            0.05       92          1  2.451106e+07        40         5
#
#    sparsity  decomposability  regularity  pictoriality  datasize_est  \
# 0        -1               -1          -1            -1         38398
# 1        -1               -1          -1            -1         28669
# 2        -1               -1          -1            -1         27481
# 3        -1               -1          -1            -1         19647
# 4        -1               -1          -1            -1         10792
#
#    datasize_real  reconstruct_snr  target_cmp  target_snr
# 0          39142        13.467377   18.473873          20
# 1          29413        19.505306   18.517654          20
# 2          28225        23.767583   18.590892          20
# 3          20391        23.742502   18.693992          20
# 4          11536        22.784839   18.827530          20

# %%
tensor_size = 128*26*26*4
df["cmp"] = tensor_size/df["datasize_real"]

# %%
jpeg_cha = pd.read_csv("/home/rex/gitRepo/split_DNN_framework/stable_tests/measurements/jpeg_snr_cha/characteristic.csv")
jpeg_cha = jpeg_cha[jpeg_cha["sparsity"]>0]
jpeg_cha = jpeg_cha[jpeg_cha["datasize_est"]>0]
tensor_size = 128*26*26 *4
jpeg_cha["ratio"] = tensor_size/jpeg_cha["datasize_est"]
pruning = [0.05, 0.1, 0.15, 0.2, 0.25,0.3,0.35]
quality = [60,70,80,90,100]

sample_points=[]
cmp_sample_values = []
snr_sample_values = []

cha_df_group =jpeg_cha.groupby("pruning_thresh")
for p in pruning:
    cha_df = cha_df_group.get_group(p)
    cha_quality_df = cha_df.groupby("quality")
    for q in quality:
        cha_plot_df= cha_quality_df.get_group(q)
        sample_points.append([q,p])
        cmp_sample_values.append(cha_plot_df["ratio"].mean())
        snr_sample_values.append(cha_plot_df["reconstruct_snr"].mean())

# %%
thresh = df["pruning_thresh"].to_numpy()
quality = df["quality"].to_numpy()
cmp_m = df["cmp"].to_numpy()

# %%
est_err = []
history_point = []
history_snr =[]
cmp_est_all = []
for i in range(len(thresh)):
    # snr_est = griddata(sample_points, sample_snrs, (thresh[i],quality[i]), method='cubic')
    snr_est = griddata(sample_points, cmp_sample_values, (quality[i],thresh[i]), method='linear')
    cmp_est_all.append(snr_est)
    est_err.append(snr_est-cmp_m[i])
    history_point.append((thresh[i],quality[i]))
    history_snr.append(cmp_m[i])

# %%
plt.figure()
plt.plot(est_err)
# plt.ylim([-50,50])
plt.grid()
plt.xlabel("video sequence")
plt.ylabel("compression ratio estimation error")
# Out:
# Text(0, 0.5, 'compression ratio estimation error')

# %%
plt.figure()
plt.plot(cmp_m, label="real")
plt.plot(cmp_est_all,label="estimation")
plt.legend()
plt.grid()
plt.xlabel("video frame sequence")
plt.ylabel("compression ratio")
# Out:
# Text(0, 0.5, 'compression ratio')

# %%
est_err_window = []
est_snr_window = []
window_size = 3
history_point = []
history_snr =[]

for i in range(len(thresh)):
    sample_points = sample_space+history_point
    sample_snrs = sample_space_cmp +history_snr
    # snr_est = griddata(sample_points, sample_snrs, (thresh[i],quality[i]), method='cubic')
    snr_est = griddata(sample_points, sample_snrs, (thresh[i],quality[i]), method='cubic')
    est_snr_window.append(snr_est)
    est_err_window.append(snr_est-cmp_m[i])

    if len(history_point)<window_size:
        history_point.append((thresh[i],quality[i]))
        history_snr.append(cmp_m[i])
    else:
        index = i%window_size
        history_point[index] = (thresh[i],quality[i])
        history_snr[index] =  cmp_m[i]

# %%
plt.figure()
plt.plot(est_err)
plt.plot(est_err_window)
plt.ylim([-50,50])
plt.grid()

# %%
plt.figure()
plt.plot(cmp_m)
plt.plot(est_snr_window)

# %%
plt.figure()
plt.plot(quality)
